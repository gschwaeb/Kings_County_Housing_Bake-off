# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
# %matplotlib inline
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('kc_house_data_train.csv', index_col = 0)

# %% [markdown]
# ### Data Cleaning

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  1.729000e+04  1.729000e+04  17290.000000  17290.000000  17290.000000
# mean   4.565502e+09  5.407395e+05      3.372470      2.111943   2081.464604
# std    2.874656e+09  3.733190e+05      0.939346      0.770476    920.018539
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.114701e+09  3.210000e+05      3.000000      1.500000   1430.000000
# 50%    3.903650e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.301150e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  1.729000e+04  17290.000000  17290.000000  17290.000000  17290.000000
# mean   1.524340e+04      1.490312      0.007981      0.238519      3.408502
# std    4.230462e+04      0.538909      0.088985      0.775229      0.651296
# min    5.720000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.081250e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.642000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.072575e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  17290.000000  17290.000000   17290.000000  17290.000000  17290.000000
# mean       7.654425   1789.306015     292.158589   1970.792019     83.806304
# std        1.174718    829.265107     443.151874     29.343516    400.329376
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1200.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1974.000000      0.000000
# 75%        8.000000   2214.500000     560.000000   1996.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  17290.000000  17290.000000  17290.000000   17290.000000   17290.000000
# mean   98078.193175     47.560058   -122.214258    1987.986698   12873.475824
# std       53.607949      0.138412      0.140857     684.802635   27227.437583
# min    98001.000000     47.155900   -122.519000     399.000000     659.000000
# 25%    98033.000000     47.471200   -122.329000    1490.000000    5111.250000
# 50%    98065.000000     47.571600   -122.230000    1840.000000    7622.500000
# 75%    98118.000000     47.677900   -122.126000    2360.000000   10101.750000
# max    98199.000000     47.777600   -121.315000    6210.000000  858132.000000

# %%
# I don't think these houses actually have 0 bathrooms, lets impute using bathrooms per sqft living
df[df['bathrooms']< .74]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 483    3374500520  20150429T000000   355000.0         0        0.0
# 1120   6306400140  20140612T000000  1095000.0         0        0.0
# 3032   7849202190  20141223T000000   235000.0         0        0.0
# 4622   7987400316  20140814T000000   255000.0         1        0.5
# 5424   3918400017  20150205T000000   380000.0         0        0.0
# 7093   7129800036  20150114T000000   109000.0         2        0.5
# 9060   3421079032  20150217T000000    75000.0         1        0.0
# 9286   2954400190  20140624T000000  1295650.0         0        0.0
# 10067  3980300371  20140926T000000   142000.0         0        0.0
# 12674  2991000160  20141212T000000   312500.0         4        0.5
# 12982   203100435  20140918T000000   484000.0         1        0.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 483           2460      8049     2.0           0     0          3      8
# 1120          3064      4764     3.5           0     2          3      7
# 3032          1470      4800     2.0           0     0          3      7
# 4622           880      1642     1.0           0     0          3      6
# 5424          1470       979     3.0           0     2          3      8
# 7093           580      6900     1.0           0     0          3      5
# 9060           670     43377     1.0           0     0          3      3
# 9286          4810     28008     2.0           0     0          3     12
# 10067          290     20875     1.0           0     0          1      1
# 12674         2300      5570     2.0           0     0          3      8
# 12982          690     23244     1.0           0     0          4      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 483          2460              0      1990             0    98031  47.4095
# 1120         3064              0      1990             0    98102  47.6362
# 3032         1470              0      1996             0    98065  47.5265
# 4622          500            380      1910             0    98126  47.5732
# 5424         1470              0      2006             0    98133  47.7145
# 7093          580              0      1941             0    98118  47.5135
# 9060          670              0      1966             0    98022  47.2638
# 9286         4810              0      1990             0    98053  47.6642
# 10067         290              0      1963             0    98024  47.5308
# 12674        2300              0      1996             0    98092  47.3285
# 12982         690              0      1948             0    98053  47.6429
#
#           long  sqft_living15  sqft_lot15
# 483   -122.168           2520        8050
# 1120  -122.322           2360        4000
# 3032  -121.828           1060        7200
# 4622  -122.372           1410        2992
# 5424  -122.356           1470        1399
# 7093  -122.262           1570        5040
# 9060  -121.906           1160       42882
# 9286  -122.069           4740       35061
# 10067 -121.888           1620       22850
# 12674 -122.168           1820        6371
# 12982 -121.955           1690       19290

# %%
bathroom_per_sqftl = (df[df['bathrooms']>0]['bathrooms'] / df[df['bathrooms']>0]['sqft_living']).mean()
bathroom_per_sqftl
# Out:
# 0.0010755476417730245

# %%
df['bathrooms'] = np.where(df['bathrooms'] < .74, np.round(df['sqft_living'] * bathroom_per_sqftl),  df['bathrooms'])

# %%
# I will do similar with bedrooms
df[df['bedrooms']< 1]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 483    3374500520  20150429T000000   355000.0         0       3.00
# 1120   6306400140  20140612T000000  1095000.0         0       3.00
# 2430   1222029077  20141029T000000   265000.0         0       0.75
# 3032   7849202190  20141223T000000   235000.0         0       2.00
# 3609   2569500210  20141117T000000   339950.0         0       2.50
# 5424   3918400017  20150205T000000   380000.0         0       2.00
# 6409   1453602309  20140805T000000   288000.0         0       1.50
# 9286   2954400190  20140624T000000  1295650.0         0       5.00
# 10067  3980300371  20140926T000000   142000.0         0       0.00
# 10074  2310060040  20140925T000000   240000.0         0       2.50
# 13989  6896300380  20141002T000000   228000.0         0       1.00
# 15733  7849202299  20150218T000000   320000.0         0       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 483           2460      8049     2.0           0     0          3      8
# 1120          3064      4764     3.5           0     2          3      7
# 2430           384    213444     1.0           0     0          3      4
# 3032          1470      4800     2.0           0     0          3      7
# 3609          2290      8319     2.0           0     0          3      8
# 5424          1470       979     3.0           0     2          3      8
# 6409          1430      1650     3.0           0     0          3      7
# 9286          4810     28008     2.0           0     0          3     12
# 10067          290     20875     1.0           0     0          1      1
# 10074         1810      5669     2.0           0     0          3      7
# 13989          390      5900     1.0           0     0          2      4
# 15733         1490      7111     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 483          2460              0      1990             0    98031  47.4095
# 1120         3064              0      1990             0    98102  47.6362
# 2430          384              0      2003             0    98070  47.4177
# 3032         1470              0      1996             0    98065  47.5265
# 3609         2290              0      1985             0    98042  47.3473
# 5424         1470              0      2006             0    98133  47.7145
# 6409         1430              0      1999             0    98125  47.7222
# 9286         4810              0      1990             0    98053  47.6642
# 10067         290              0      1963             0    98024  47.5308
# 10074        1810              0      2003             0    98038  47.3493
# 13989         390              0      1953             0    98118  47.5260
# 15733        1490              0      1999             0    98065  47.5261
#
#           long  sqft_living15  sqft_lot15
# 483   -122.168           2520        8050
# 1120  -122.322           2360        4000
# 2430  -122.491           1920      224341
# 3032  -121.828           1060        7200
# 3609  -122.151           2500        8751
# 5424  -122.356           1470        1399
# 6409  -122.290           1430        1650
# 9286  -122.069           4740       35061
# 10067 -121.888           1620       22850
# 10074 -122.053           1810        5685
# 13989 -122.261           2170        6000
# 15733 -121.826           1500        4675

# %%
bedrooms_per_sqftl =  (df[df['bedrooms']>0]['bedrooms'] / df[df['bedrooms']>0]['sqft_living']).mean()
bedrooms_per_sqftl*2920
# Out:
# 5.2420867982507975

# %%
df['bedrooms'] = np.where(df['bedrooms'] < 1, np.round(df['sqft_living'] * bedrooms_per_sqftl),  df['bedrooms'])

# %%
df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006T000000   365000.0       4.0       2.25         2070
# 1  7974200820  20140821T000000   865000.0       5.0       3.00         2900
# 2  7701450110  20140815T000000  1038000.0       4.0       2.50         3770
# 3  9522300010  20150331T000000  1490000.0       3.0       3.50         4560
# 4  9510861140  20140714T000000   711000.0       3.0       2.50         2550
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      8893     2.0           0     0          4      8        2070
# 1      6730     1.0           0     0          5      8        1830
# 2     10893     2.0           0     2          3     11        3770
# 3     14608     2.0           0     2          3     12        4560
# 4      5376     2.0           0     0          3      9        2550
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1986             0    98058  47.4388 -122.162
# 1           1070      1977             0    98115  47.6784 -122.285
# 2              0      1997             0    98006  47.5646 -122.129
# 3              0      1990             0    98034  47.6995 -122.228
# 4              0      2004             0    98052  47.6647 -122.083
#
#    sqft_living15  sqft_lot15
# 0           2390        7700
# 1           2370        6283
# 2           3710        9685
# 3           4050       14226
# 4           2250        4050

# %%
#let's see where there is way more bedrooms then there should be given the living space. More likely than not, this will throw off the model, so let's adjust
df[df['bedrooms'] > (bedrooms_per_sqftl*df['sqft_living']+5)]
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 2356  1773100755  20140821T000000  520000.0      11.0       3.00         3000
# 8597  2402100895  20140625T000000  640000.0      33.0       1.75         1620
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2356      4960     2.0           0     0          3      7        2400
# 8597      6000     1.0           0     0          5      7        1040
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 2356            600      1918          1999    98106  47.5560 -122.363
# 8597            580      1947             0    98103  47.6878 -122.331
#
#       sqft_living15  sqft_lot15
# 2356           1420        4960
# 8597           1330        4700

# %%
df['bedrooms'] = np.where(df['bedrooms'] > (bedrooms_per_sqftl*df['sqft_living']+5), np.round(df['sqft_living'] * bedrooms_per_sqftl),  df['bedrooms'])

# %%
df[df['bedrooms'] > (bedrooms_per_sqftl*df['sqft_living']+5)]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
#i know sqft_living will be a significant feature, lset try capping it at 6 std above the mean so we dont have huge outliers
df[df['sqft_living'] > (df['sqft_living'].mean() + (6*df['sqft_living'].std()))]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1979   8907500070  20150413T000000  5350000.0       5.0       5.00
# 2232   2470100110  20140804T000000  5570000.0       5.0       5.75
# 3275   1225069038  20140505T000000  2280000.0       7.0       8.00
# 3316   3459900230  20141125T000000  1680000.0       4.0       3.75
# 3757   1346300150  20141020T000000  3300000.0       8.0       4.00
# 4217   2303900035  20140611T000000  2888000.0       5.0       6.25
# 6903   9808700762  20140611T000000  7062500.0       5.0       4.50
# 7183   6072800246  20140702T000000  3300000.0       5.0       6.25
# 7519   9208900037  20140919T000000  6885000.0       6.0       7.75
# 10366  6762700020  20141013T000000  7700000.0       6.0       8.00
# 12243  1630700380  20150130T000000  1920000.0       5.0       5.75
# 14668  1247600105  20141020T000000  5110800.0       5.0       5.25
# 14919  2524069078  20150122T000000  2700000.0       4.0       4.00
# 15816  1924059029  20140617T000000  4668000.0       5.0       6.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 1979          8000     23985     2.0           0     4          3     12
# 2232          9200     35069     2.0           0     0          3     13
# 3275         13540    307752     3.0           0     4          3     12
# 3316          7620     29536     2.0           0     3          3     11
# 3757          7710     11750     3.5           0     0          5     12
# 4217          8670     64033     2.0           0     4          3     13
# 6903         10040     37325     2.0           1     2          3     11
# 7183          8020     21738     2.0           0     0          3     11
# 7519          9890     31374     2.0           0     4          3     13
# 10366        12050     27600     2.5           0     3          4     13
# 12243         7730    230868     2.0           0     0          3     12
# 14668         8010     45517     2.0           1     4          3     12
# 14919         7850     89651     2.0           0     0          3     12
# 15816         9640     13068     1.0           1     4          3     12
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 1979         6720           1280      2009             0    98004  47.6232
# 2232         6200           3000      2001             0    98039  47.6289
# 3275         9410           4130      1999             0    98053  47.6675
# 3316         5980           1640      2005             0    98006  47.5571
# 3757         6090           1620      1904             0    98112  47.6263
# 4217         6120           2550      1965          2003    98177  47.7295
# 6903         7680           2360      1940          2001    98004  47.6500
# 7183         8020              0      2001             0    98006  47.5675
# 7519         8860           1030      2001             0    98039  47.6305
# 10366        8570           3480      1910          1987    98102  47.6298
# 12243        6660           1070      2004             0    98077  47.7615
# 14668        5990           2020      1999             0    98033  47.6767
# 14919        7850              0      2006             0    98027  47.5406
# 15816        4820           4820      1983          2009    98040  47.5570
#
#           long  sqft_living15  sqft_lot15
# 1979  -122.220           4600       21750
# 2232  -122.233           3560       24345
# 3275  -121.986           4850      217800
# 3316  -122.140           2840       20809
# 3757  -122.314           4210        8325
# 4217  -122.372           4140       81021
# 6903  -122.214           3930       25449
# 7183  -122.189           4160       18969
# 7519  -122.240           4540       42730
# 10366 -122.323           3940        8800
# 12243 -122.084           2660       39292
# 14668 -122.211           3430       26788
# 14919 -121.982           6210       95832
# 15816 -122.210           3270       10454

# %%
sqft_living_cap = df['sqft_living'].mean() + (6*df['sqft_living'].std())
sqft_living_cap
# Out:
# 7601.575840208134

# %%
df['sqft_living'] = np.where(df['sqft_living'] > sqft_living_cap,
                            sqft_living_cap,
                             df['sqft_living'])

# %%
df[df['sqft_living'] > sqft_living_cap]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %% [markdown]
# ## Feature Engineering

# %%
df['year'] = df['date'].apply(lambda x: int(x[0:4]))

df['month_sold'] = df['date'].apply(lambda x: int(x[4:6]))

df['year_most_recent_construction'] = np.where(df['yr_renovated'] > df['yr_built'], df['yr_renovated'], df['yr_built'])

df['years_since_most_recent_construction'] = df['year'] - df['year_most_recent_construction']

#take out any negative values
df['years_since_most_recent_construction'] = np.where(df['years_since_most_recent_construction'] <0, 0, df['years_since_most_recent_construction'])

df['yard'] = df['sqft_lot'] - (df['sqft_living']/df['floors'])

df['excess_bathrooms'] = np.ceil(df['bathrooms'] - df['bedrooms'])

df['decade_built'] = df['yr_built'].apply(lambda x: str(x)[0:3]+'0s')

df['grade_cat'] = np.where(df['grade'] < 6, 'low_grade', df['grade'])

df['waterfront_view'] = df['waterfront'] * df['view']

# %%
conditions = [df['month_sold'] == 1,
              df['month_sold'] == 2,
              df['month_sold'] == 3,
              df['month_sold'] == 4,
              df['month_sold'] == 5,
              df['month_sold'] == 6,
              df['month_sold'] == 7,
              df['month_sold']  == 8,
              df['month_sold']  == 9,
              df['month_sold']  == 10,
              df['month_sold']  == 11,
              df['month_sold']  == 12
             ]

choices = ['Winter',
           'Winter',
           'Spring',
           'Spring',
           'Spring',
          'Summer',
          'Summer',
          'Summer',
          'Fall',
          'Fall',
          'Fall',
          'Winter']
           
    
df['season_sold'] = np.select(conditions, choices, default = np.NaN)

# %%
conditions = [df['excess_bathrooms'] <= -2,
              df['excess_bathrooms'] == -1,
              df['excess_bathrooms'] == 0,
              df['excess_bathrooms'] >= 1,

             ]

choices = ['2_or_less',
           '1_less',
           'parity',
           '1_or_more',]
           
    
df['excess_bathrooms_cat'] = np.select(conditions, choices)

# %%
conditions = [df['decade_built'] == '1900s',
              df['decade_built'] == '1910s',
              df['decade_built'] == '1920s',
              df['decade_built'] == '1930s',
             ]

choices = ['Pre-war',
           'Pre-war',
           'Pre-war',
           'Pre-war']
           
    


df['decade_built_adjusted'] = np.select(conditions, choices, default = df['decade_built'])

# %%
conditions = [df['view'] == 0,
              df['view'] == 1,
              df['view'] == 2,
              df['view'] == 3,
              df['view'] == 4
             ]

choices = ['no_view',
           'ok_view',
           'ok_view',
           'good_view',
          'great_view']
           
    

df['view_cat'] = np.select(conditions, choices)

# %%
#importing zipcode level info
#https://www.reddit.com/r/datasets/comments/hixfeo/how_to_obtain_median_income_data_for_zip_codes/
zipcodes = pd.read_csv('ACSST5Y2019.S1901_data_with_overlays_2021-03-08T095143.csv', index_col = 0, header = 1)

# %%
zipcodes.head()
# Out:
#                Geographic Area Name  Estimate!!Households!!Total  \
# id
# 8600000US98001          ZCTA5 98001                        11247
# 8600000US98002          ZCTA5 98002                        13475
# 8600000US98003          ZCTA5 98003                        18547
# 8600000US98004          ZCTA5 98004                        17070
# 8600000US98005          ZCTA5 98005                         8008
#
#                 Margin of Error!!Households!!Total  \
# id
# 8600000US98001                                 287
# 8600000US98002                                 465
# 8600000US98003                                 524
# 8600000US98004                                 387
# 8600000US98005                                 311
#
#                Estimate!!Households!!Total!!Less than $10,000  \
# id
# 8600000US98001                                            2.7
# 8600000US98002                                            4.9
# 8600000US98003                                            7.1
# 8600000US98004                                            3.7
# 8600000US98005                                            3.3
#
#                Margin of Error!!Households!!Total!!Less than $10,000  \
# id
# 8600000US98001                                                0.9
# 8600000US98002                                                1.4
# 8600000US98003                                                1.5
# 8600000US98004                                                1.1
# 8600000US98005                                                1.7
#
#                Estimate!!Households!!Total!!$10,000 to $14,999  \
# id
# 8600000US98001                                             1.5
# 8600000US98002                                             3.5
# 8600000US98003                                             4.8
# 8600000US98004                                             1.7
# 8600000US98005                                             3.4
#
#                Margin of Error!!Households!!Total!!$10,000 to $14,999  \
# id
# 8600000US98001                                                0.6
# 8600000US98002                                                1.1
# 8600000US98003                                                1.2
# 8600000US98004                                                0.7
# 8600000US98005                                                1.5
#
#                Estimate!!Households!!Total!!$15,000 to $24,999  \
# id
# 8600000US98001                                             4.5
# 8600000US98002                                             9.1
# 8600000US98003                                             6.2
# 8600000US98004                                             3.0
# 8600000US98005                                             3.6
#
#                Margin of Error!!Households!!Total!!$15,000 to $24,999  \
# id
# 8600000US98001                                                1.4
# 8600000US98002                                                1.7
# 8600000US98003                                                1.7
# 8600000US98004                                                0.9
# 8600000US98005                                                1.3
#
#                Estimate!!Households!!Total!!$25,000 to $34,999  \
# id
# 8600000US98001                                             3.9
# 8600000US98002                                            11.5
# 8600000US98003                                             9.6
# 8600000US98004                                             2.7
# 8600000US98005                                             2.8
#
#                Margin of Error!!Households!!Total!!$25,000 to $34,999  \
# id
# 8600000US98001                                                1.0
# 8600000US98002                                                2.0
# 8600000US98003                                                1.6
# 8600000US98004                                                0.8
# 8600000US98005                                                1.3
#
#                Estimate!!Households!!Total!!$35,000 to $49,999  \
# id
# 8600000US98001                                             8.4
# 8600000US98002                                            13.8
# 8600000US98003                                            14.3
# 8600000US98004                                             5.1
# 8600000US98005                                             5.6
#
#                Margin of Error!!Households!!Total!!$35,000 to $49,999  \
# id
# 8600000US98001                                                1.6
# 8600000US98002                                                2.2
# 8600000US98003                                                2.1
# 8600000US98004                                                1.3
# 8600000US98005                                                1.4
#
#                Estimate!!Households!!Total!!$50,000 to $74,999  \
# id
# 8600000US98001                                            19.3
# 8600000US98002                                            22.9
# 8600000US98003                                            21.9
# 8600000US98004                                             8.8
# 8600000US98005                                            10.8
#
#                Margin of Error!!Households!!Total!!$50,000 to $74,999  \
# id
# 8600000US98001                                                2.8
# 8600000US98002                                                2.8
# 8600000US98003                                                2.4
# 8600000US98004                                                1.5
# 8600000US98005                                                1.9
#
#                Estimate!!Households!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                            15.1
# 8600000US98002                                            13.5
# 8600000US98003                                            12.2
# 8600000US98004                                            10.2
# 8600000US98005                                            11.7
#
#                Margin of Error!!Households!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                                2.5
# 8600000US98002                                                2.4
# 8600000US98003                                                1.9
# 8600000US98004                                                1.7
# 8600000US98005                                                2.5
#
#                Estimate!!Households!!Total!!$100,000 to $149,999  \
# id
# 8600000US98001                                              26.4
# 8600000US98002                                              14.0
# 8600000US98003                                              14.1
# 8600000US98004                                              19.5
# 8600000US98005                                              19.1
#
#                Margin of Error!!Households!!Total!!$100,000 to $149,999  \
# id
# 8600000US98001                                                2.7
# 8600000US98002                                                2.2
# 8600000US98003                                                1.7
# 8600000US98004                                                2.2
# 8600000US98005                                                3.1
#
#                Estimate!!Households!!Total!!$150,000 to $199,999  \
# id
# 8600000US98001                                              10.8
# 8600000US98002                                               3.9
# 8600000US98003                                               5.8
# 8600000US98004                                              12.6
# 8600000US98005                                              15.2
#
#                Margin of Error!!Households!!Total!!$150,000 to $199,999  \
# id
# 8600000US98001                                                1.9
# 8600000US98002                                                1.2
# 8600000US98003                                                1.2
# 8600000US98004                                                1.7
# 8600000US98005                                                2.4
#
#                Estimate!!Households!!Total!!$200,000 or more  \
# id
# 8600000US98001                                           7.3
# 8600000US98002                                           2.9
# 8600000US98003                                           4.0
# 8600000US98004                                          32.7
# 8600000US98005                                          24.2
#
#                Margin of Error!!Households!!Total!!$200,000 or more  \
# id
# 8600000US98001                                                1.8
# 8600000US98002                                                1.1
# 8600000US98003                                                1.0
# 8600000US98004                                                2.3
# 8600000US98005                                                3.0
#
#                Estimate!!Households!!Median income (dollars)  \
# id
# 8600000US98001                                         90287
# 8600000US98002                                         57317
# 8600000US98003                                         59391
# 8600000US98004                                        134580
# 8600000US98005                                        120913
#
#                Margin of Error!!Households!!Median income (dollars)  \
# id
# 8600000US98001                                               7079
# 8600000US98002                                               2210
# 8600000US98003                                               2630
# 8600000US98004                                               8268
# 8600000US98005                                               6793
#
#                Estimate!!Households!!Mean income (dollars)  \
# id
# 8600000US98001                                      102055
# 8600000US98002                                       68474
# 8600000US98003                                       75321
# 8600000US98004                                      197786
# 8600000US98005                                      157377
#
#                Margin of Error!!Households!!Mean income (dollars)  \
# id
# 8600000US98001                                               4442
# 8600000US98002                                               3911
# 8600000US98003                                               3494
# 8600000US98004                                              10372
# 8600000US98005                                               9963
#
#                Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# id
# 8600000US98001                                               30.8
# 8600000US98002                                               28.3
# 8600000US98003                                               32.1
# 8600000US98004                                               23.0
# 8600000US98005                                               24.0
#
#                Margin of Error!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Estimate!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Margin of Error!!Households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Estimate!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Margin of Error!!Households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                 Estimate!!Families!!Total  Margin of Error!!Families!!Total  \
# id
# 8600000US98001                       8554                               383
# 8600000US98002                       7921                               330
# 8600000US98003                      11657                               532
# 8600000US98004                       9651                               479
# 8600000US98005                       5003                               327
#
#                Estimate!!Families!!Total!!Less than $10,000  \
# id
# 8600000US98001                                          1.4
# 8600000US98002                                          5.0
# 8600000US98003                                          6.2
# 8600000US98004                                          1.0
# 8600000US98005                                          2.8
#
#                Margin of Error!!Families!!Total!!Less than $10,000  \
# id
# 8600000US98001                                                0.6
# 8600000US98002                                                2.0
# 8600000US98003                                                1.9
# 8600000US98004                                                0.5
# 8600000US98005                                                2.2
#
#                Estimate!!Families!!Total!!$10,000 to $14,999  \
# id
# 8600000US98001                                           0.7
# 8600000US98002                                           1.8
# 8600000US98003                                           2.5
# 8600000US98004                                           0.5
# 8600000US98005                                           1.0
#
#                Margin of Error!!Families!!Total!!$10,000 to $14,999  \
# id
# 8600000US98001                                                0.6
# 8600000US98002                                                0.9
# 8600000US98003                                                1.1
# 8600000US98004                                                0.4
# 8600000US98005                                                0.8
#
#                Estimate!!Families!!Total!!$15,000 to $24,999  \
# id
# 8600000US98001                                           3.4
# 8600000US98002                                           5.6
# 8600000US98003                                           5.0
# 8600000US98004                                           1.9
# 8600000US98005                                           2.2
#
#                Margin of Error!!Families!!Total!!$15,000 to $24,999  \
# id
# 8600000US98001                                                1.7
# 8600000US98002                                                1.9
# 8600000US98003                                                1.8
# 8600000US98004                                                1.0
# 8600000US98005                                                1.1
#
#                Estimate!!Families!!Total!!$25,000 to $34,999  \
# id
# 8600000US98001                                           3.5
# 8600000US98002                                           9.2
# 8600000US98003                                           8.5
# 8600000US98004                                           1.8
# 8600000US98005                                           2.5
#
#                Margin of Error!!Families!!Total!!$25,000 to $34,999  \
# id
# 8600000US98001                                                1.5
# 8600000US98002                                                2.8
# 8600000US98003                                                1.9
# 8600000US98004                                                0.9
# 8600000US98005                                                1.8
#
#                Estimate!!Families!!Total!!$35,000 to $49,999  \
# id
# 8600000US98001                                           7.8
# 8600000US98002                                          12.2
# 8600000US98003                                          12.5
# 8600000US98004                                           3.0
# 8600000US98005                                           1.5
#
#                Margin of Error!!Families!!Total!!$35,000 to $49,999  \
# id
# 8600000US98001                                                1.9
# 8600000US98002                                                2.6
# 8600000US98003                                                2.6
# 8600000US98004                                                1.1
# 8600000US98005                                                0.9
#
#                Estimate!!Families!!Total!!$50,000 to $74,999  \
# id
# 8600000US98001                                          18.4
# 8600000US98002                                          22.9
# 8600000US98003                                          22.5
# 8600000US98004                                           6.9
# 8600000US98005                                           6.8
#
#                Margin of Error!!Families!!Total!!$50,000 to $74,999  \
# id
# 8600000US98001                                                2.7
# 8600000US98002                                                4.0
# 8600000US98003                                                3.6
# 8600000US98004                                                1.9
# 8600000US98005                                                2.1
#
#                Estimate!!Families!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                          16.9
# 8600000US98002                                          16.4
# 8600000US98003                                          13.1
# 8600000US98004                                           8.3
# 8600000US98005                                          11.8
#
#                Margin of Error!!Families!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                                3.1
# 8600000US98002                                                3.4
# 8600000US98003                                                2.5
# 8600000US98004                                                2.2
# 8600000US98005                                                2.6
#
#                Estimate!!Families!!Total!!$100,000 to $149,999  ...  \
# id                                                              ...
# 8600000US98001                                            27.3  ...
# 8600000US98002                                            17.9  ...
# 8600000US98003                                            17.3  ...
# 8600000US98004                                            16.4  ...
# 8600000US98005                                            21.9  ...
#
#                Estimate!!Married-couple families!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                               17.1
# 8600000US98002                                               20.3
# 8600000US98003                                               14.8
# 8600000US98004                                                7.7
# 8600000US98005                                               11.6
#
#                Margin of Error!!Married-couple families!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                                3.3
# 8600000US98002                                                4.8
# 8600000US98003                                                2.9
# 8600000US98004                                                2.4
# 8600000US98005                                                2.7
#
#                Estimate!!Married-couple families!!Total!!$100,000 to $149,999  \
# id
# 8600000US98001                                               32.1
# 8600000US98002                                               22.7
# 8600000US98003                                               21.5
# 8600000US98004                                               17.7
# 8600000US98005                                               20.6
#
#                Margin of Error!!Married-couple families!!Total!!$100,000 to $149,999  \
# id
# 8600000US98001                                                3.9
# 8600000US98002                                                4.3
# 8600000US98003                                                3.1
# 8600000US98004                                                3.1
# 8600000US98005                                                3.7
#
#                Estimate!!Married-couple families!!Total!!$150,000 to $199,999  \
# id
# 8600000US98001                                               14.2
# 8600000US98002                                                9.1
# 8600000US98003                                               10.4
# 8600000US98004                                               17.2
# 8600000US98005                                               21.3
#
#                Margin of Error!!Married-couple families!!Total!!$150,000 to $199,999  \
# id
# 8600000US98001                                                2.8
# 8600000US98002                                                2.8
# 8600000US98003                                                2.8
# 8600000US98004                                                2.5
# 8600000US98005                                                3.8
#
#                Estimate!!Married-couple families!!Total!!$200,000 or more  \
# id
# 8600000US98001                                               10.0
# 8600000US98002                                                3.3
# 8600000US98003                                                7.6
# 8600000US98004                                               47.0
# 8600000US98005                                               33.1
#
#                Margin of Error!!Married-couple families!!Total!!$200,000 or more  \
# id
# 8600000US98001                                                2.5
# 8600000US98002                                                1.7
# 8600000US98003                                                2.3
# 8600000US98004                                                3.7
# 8600000US98005                                                4.2
#
#                Estimate!!Married-couple families!!Median income (dollars)  \
# id
# 8600000US98001                                             104731
# 8600000US98002                                              79918
# 8600000US98003                                              83367
# 8600000US98004                                             188228
# 8600000US98005                                             157403
#
#                Margin of Error!!Married-couple families!!Median income (dollars)  \
# id
# 8600000US98001                                               4106
# 8600000US98002                                               4219
# 8600000US98003                                               9137
# 8600000US98004                                               9024
# 8600000US98005                                               9561
#
#                Estimate!!Married-couple families!!Mean income (dollars)  \
# id
# 8600000US98001                                                  N
# 8600000US98002                                                  N
# 8600000US98003                                                  N
# 8600000US98004                                                  N
# 8600000US98005                                                  N
#
#                Margin of Error!!Married-couple families!!Mean income (dollars)  \
# id
# 8600000US98001                                                  N
# 8600000US98002                                                  N
# 8600000US98003                                                  N
# 8600000US98004                                                  N
# 8600000US98005                                                  N
#
#                Estimate!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Estimate!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                 Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                 Estimate!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Margin of Error!!Married-couple families!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Estimate!!Nonfamily households!!Total  \
# id
# 8600000US98001                                  2693
# 8600000US98002                                  5554
# 8600000US98003                                  6890
# 8600000US98004                                  7419
# 8600000US98005                                  3005
#
#                Margin of Error!!Nonfamily households!!Total  \
# id
# 8600000US98001                                          357
# 8600000US98002                                          525
# 8600000US98003                                          575
# 8600000US98004                                          574
# 8600000US98005                                          324
#
#                Estimate!!Nonfamily households!!Total!!Less than $10,000  \
# id
# 8600000US98001                                                7.6
# 8600000US98002                                                7.7
# 8600000US98003                                                9.9
# 8600000US98004                                                7.3
# 8600000US98005                                                4.4
#
#                Margin of Error!!Nonfamily households!!Total!!Less than $10,000  \
# id
# 8600000US98001                                                3.1
# 8600000US98002                                                2.6
# 8600000US98003                                                2.6
# 8600000US98004                                                2.4
# 8600000US98005                                                3.0
#
#                Estimate!!Nonfamily households!!Total!!$10,000 to $14,999  \
# id
# 8600000US98001                                                4.0
# 8600000US98002                                                6.0
# 8600000US98003                                                9.5
# 8600000US98004                                                3.2
# 8600000US98005                                                7.4
#
#                Margin of Error!!Nonfamily households!!Total!!$10,000 to $14,999  \
# id
# 8600000US98001                                                1.9
# 8600000US98002                                                2.2
# 8600000US98003                                                3.0
# 8600000US98004                                                1.3
# 8600000US98005                                                3.9
#
#                Estimate!!Nonfamily households!!Total!!$15,000 to $24,999  \
# id
# 8600000US98001                                               10.4
# 8600000US98002                                               16.0
# 8600000US98003                                               10.9
# 8600000US98004                                                4.6
# 8600000US98005                                                6.3
#
#                Margin of Error!!Nonfamily households!!Total!!$15,000 to $24,999  \
# id
# 8600000US98001                                                4.4
# 8600000US98002                                                3.9
# 8600000US98003                                                3.5
# 8600000US98004                                                1.7
# 8600000US98005                                                2.7
#
#                Estimate!!Nonfamily households!!Total!!$25,000 to $34,999  \
# id
# 8600000US98001                                                7.7
# 8600000US98002                                               14.4
# 8600000US98003                                               11.9
# 8600000US98004                                                4.0
# 8600000US98005                                                3.4
#
#                Margin of Error!!Nonfamily households!!Total!!$25,000 to $34,999  \
# id
# 8600000US98001                                                3.3
# 8600000US98002                                                3.3
# 8600000US98003                                                2.9
# 8600000US98004                                                1.4
# 8600000US98005                                                1.9
#
#                Estimate!!Nonfamily households!!Total!!$35,000 to $49,999  \
# id
# 8600000US98001                                               13.3
# 8600000US98002                                               15.2
# 8600000US98003                                               18.2
# 8600000US98004                                                8.1
# 8600000US98005                                               12.8
#
#                Margin of Error!!Nonfamily households!!Total!!$35,000 to $49,999  \
# id
# 8600000US98001                                                4.9
# 8600000US98002                                                3.3
# 8600000US98003                                                3.7
# 8600000US98004                                                2.5
# 8600000US98005                                                3.4
#
#                Estimate!!Nonfamily households!!Total!!$50,000 to $74,999  \
# id
# 8600000US98001                                               21.5
# 8600000US98002                                               21.7
# 8600000US98003                                               21.1
# 8600000US98004                                               11.6
# 8600000US98005                                               17.8
#
#                Margin of Error!!Nonfamily households!!Total!!$50,000 to $74,999  \
# id
# 8600000US98001                                                6.4
# 8600000US98002                                                4.2
# 8600000US98003                                                3.8
# 8600000US98004                                                2.7
# 8600000US98005                                                4.4
#
#                Estimate!!Nonfamily households!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                                7.6
# 8600000US98002                                                8.9
# 8600000US98003                                                8.2
# 8600000US98004                                               13.2
# 8600000US98005                                               12.2
#
#                Margin of Error!!Nonfamily households!!Total!!$75,000 to $99,999  \
# id
# 8600000US98001                                                2.7
# 8600000US98002                                                2.9
# 8600000US98003                                                2.6
# 8600000US98004                                                2.9
# 8600000US98005                                                4.9
#
#                Estimate!!Nonfamily households!!Total!!$100,000 to $149,999  \
# id
# 8600000US98001                                               20.7
# 8600000US98002                                                7.2
# 8600000US98003                                                7.1
# 8600000US98004                                               23.2
# 8600000US98005                                               16.4
#
#                Margin of Error!!Nonfamily households!!Total!!$100,000 to $149,999  \
# id
# 8600000US98001                                                6.3
# 8600000US98002                                                2.9
# 8600000US98003                                                2.2
# 8600000US98004                                                3.7
# 8600000US98005                                                5.9
#
#                Estimate!!Nonfamily households!!Total!!$150,000 to $199,999  \
# id
# 8600000US98001                                                6.5
# 8600000US98002                                                0.5
# 8600000US98003                                                1.8
# 8600000US98004                                                8.0
# 8600000US98005                                                7.4
#
#                Margin of Error!!Nonfamily households!!Total!!$150,000 to $199,999  \
# id
# 8600000US98001                                                3.7
# 8600000US98002                                                0.5
# 8600000US98003                                                0.8
# 8600000US98004                                                2.0
# 8600000US98005                                                3.4
#
#                Estimate!!Nonfamily households!!Total!!$200,000 or more  \
# id
# 8600000US98001                                                0.6
# 8600000US98002                                                2.6
# 8600000US98003                                                1.3
# 8600000US98004                                               16.9
# 8600000US98005                                               12.0
#
#                Margin of Error!!Nonfamily households!!Total!!$200,000 or more  \
# id
# 8600000US98001                                                0.6
# 8600000US98002                                                1.9
# 8600000US98003                                                1.1
# 8600000US98004                                                3.2
# 8600000US98005                                                3.1
#
#                Estimate!!Nonfamily households!!Median income (dollars)  \
# id
# 8600000US98001                                              61424
# 8600000US98002                                              39739
# 8600000US98003                                              40134
# 8600000US98004                                              96075
# 8600000US98005                                              72466
#
#                Margin of Error!!Nonfamily households!!Median income (dollars)  \
# id
# 8600000US98001                                               8812
# 8600000US98002                                               3940
# 8600000US98003                                               3426
# 8600000US98004                                               6291
# 8600000US98005                                              11365
#
#                Estimate!!Nonfamily households!!Mean income (dollars)  \
# id
# 8600000US98001                                              72939
# 8600000US98002                                              51379
# 8600000US98003                                              52324
# 8600000US98004                                             135058
# 8600000US98005                                              96836
#
#                Margin of Error!!Nonfamily households!!Mean income (dollars)  \
# id
# 8600000US98001                                               7776
# 8600000US98002                                               5020
# 8600000US98003                                               6051
# 8600000US98004                                              13847
# 8600000US98005                                              10888
#
#                Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Household income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                 Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Family income in the past 12 months  \
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
#                 Estimate!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months  \
# id
# 8600000US98001                                               30.0
# 8600000US98002                                               27.4
# 8600000US98003                                               29.8
# 8600000US98004                                               16.9
# 8600000US98005                                               24.6
#
#                Margin of Error!!Nonfamily households!!PERCENT ALLOCATED!!Nonfamily income in the past 12 months
# id
# 8600000US98001                                                (X)
# 8600000US98002                                                (X)
# 8600000US98003                                                (X)
# 8600000US98004                                                (X)
# 8600000US98005                                                (X)
#
# [5 rows x 129 columns]

# %%
zipcodes['zipcode'] = zipcodes['Geographic Area Name'].apply(lambda x: int(x[6:]))

# %%
#filter by columns that may be of interest
zipcodes = zipcodes[['Estimate!!Households!!Total','Estimate!!Households!!Median income (dollars)', 'Estimate!!Households!!Mean income (dollars)', 'Estimate!!Families!!Total', 'zipcode']]

# %%
df = pd.merge(left = df, right =  zipcodes, on = 'zipcode', how = 'left')

# %%
#fix column names for readability
df.rename(columns = {'Estimate!!Households!!Total': 'zip_total_households',
                     'Estimate!!Households!!Median income (dollars)': 'zip_median_income',
                   'Estimate!!Households!!Mean income (dollars)' : 'zip_mean_income',
                   'Estimate!!Families!!Total' : 'zip_total_families'},
                      inplace = True
                        )

# %%
df['zip_median_income'] = df['zip_median_income'].astype(int)
df['zip_mean_income'] = df['zip_mean_income'].astype(int)
df['zip_total_households'] = df['zip_total_households'].astype(int)
df['zip_total_families'] = df['zip_total_families'].astype(int)
#new feature
df['zip_family_ratio'] = df['zip_total_families'] / df['zip_total_households']

# %%
df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006T000000   365000.0       4.0       2.25       2070.0
# 1  7974200820  20140821T000000   865000.0       5.0       3.00       2900.0
# 2  7701450110  20140815T000000  1038000.0       4.0       2.50       3770.0
# 3  9522300010  20150331T000000  1490000.0       3.0       3.50       4560.0
# 4  9510861140  20140714T000000   711000.0       3.0       2.50       2550.0
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      8893     2.0           0     0          4      8        2070
# 1      6730     1.0           0     0          5      8        1830
# 2     10893     2.0           0     2          3     11        3770
# 3     14608     2.0           0     2          3     12        4560
# 4      5376     2.0           0     0          3      9        2550
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1986             0    98058  47.4388 -122.162
# 1           1070      1977             0    98115  47.6784 -122.285
# 2              0      1997             0    98006  47.5646 -122.129
# 3              0      1990             0    98034  47.6995 -122.228
# 4              0      2004             0    98052  47.6647 -122.083
#
#    sqft_living15  sqft_lot15  year  month_sold  year_most_recent_construction  \
# 0           2390        7700  2014          10                           1986
# 1           2370        6283  2014           8                           1977
# 2           3710        9685  2014           8                           1997
# 3           4050       14226  2015           3                           1990
# 4           2250        4050  2014           7                           2004
#
#    years_since_most_recent_construction     yard  excess_bathrooms  \
# 0                                    28   7858.0              -1.0
# 1                                    37   3830.0              -2.0
# 2                                    17   9008.0              -1.0
# 3                                    25  12328.0               1.0
# 4                                    10   4101.0              -0.0
#
#   decade_built grade_cat  waterfront_view season_sold excess_bathrooms_cat  \
# 0        1980s         8                0        Fall               1_less
# 1        1970s         8                0      Summer            2_or_less
# 2        1990s        11                0      Summer               1_less
# 3        1990s        12                0      Spring            1_or_more
# 4        2000s         9                0      Summer               parity
#
#   decade_built_adjusted view_cat  zip_total_households  zip_median_income  \
# 0                 1980s  no_view                 15830              92225
# 1                 1970s  no_view                 22922             111569
# 2                 1990s  ok_view                 13337             144247
# 3                 1990s  ok_view                 17646             101674
# 4                 2000s  no_view                 28022             135287
#
#    zip_mean_income  zip_total_families  zip_family_ratio
# 0           107395               11422          0.721541
# 1           147430               12426          0.542099
# 2           186548               10531          0.789608
# 3           128063               11334          0.642299
# 4           161369               18806          0.671116

# %%
#should i use zip_median or zip_mean?
df.loc[:,['price', 'zip_median_income', 'zip_mean_income']].corr()
# Out:
#                       price  zip_median_income  zip_mean_income
# price              1.000000           0.399556         0.514532
# zip_median_income  0.399556           1.000000         0.944533
# zip_mean_income    0.514532           0.944533         1.000000

# %%
#zip_mean_income has a higher correlation, so I will drop zip_median_income
df.drop(columns = ['zip_median_income'], inplace = True)

# %%
#let create some interaction features to see if they end up useful in any of the models
df['zip_incomeXsqft_living'] = df['zip_mean_income'] * df['sqft_living']
df['waterfrontXsqft_living'] = df['waterfront'] * df['sqft_living']

# %%
df['zip_incomeXsqft_lot'] = df['zip_mean_income'] * df['sqft_lot']
df['sqft_living^2'] = df['sqft_living']**2
df['year_since_mrcXgrade'] = df['years_since_most_recent_construction'] * df['grade']
df['yearsince_mrcXcondition'] = df['years_since_most_recent_construction'] * df['condition']
df['yearsince_mrcXsqft_living'] = df['years_since_most_recent_construction']  * df['sqft_living']

# %%
#dropped data from first step,  may not do this for prediction
#this house with 33 bedrooms doesnt make sense. I will drop it
# df.drop(index = 8597, inplace=True)
# df = df[df['sqft_living'] < 8000]
# df = df[df['bedrooms']> 0]

# %%
df_dummy = pd.get_dummies(df, columns=['season_sold', 'condition'], drop_first=True)
df_dummy = pd.get_dummies(df_dummy, columns = ['grade_cat']).drop(columns = 'grade_cat_low_grade', axis = 1)
df_dummy = pd.get_dummies(df_dummy, columns = ['view_cat']).drop(columns = 'view_cat_no_view', axis = 1)
df_dummy = pd.get_dummies(df_dummy, columns = ['excess_bathrooms_cat']).drop(columns = 'excess_bathrooms_cat_parity', axis = 1)
df = pd.get_dummies(df_dummy, columns = ['decade_built_adjusted']).drop(columns = 'decade_built_adjusted_2010s', axis = 1)

# %%
#dropping columns i preferred to categorize
df.drop(columns = ['decade_built', 'excess_bathrooms'], inplace = True)

# %% [markdown]
# ---

# %% [markdown]
# Writing functions to quickly get testing and training RMSE's on my models for both price and log price

# %%
def test_data(features, target):
    X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 15, test_size=0.2)
    #instantiate a linear regression object
    lm = LinearRegression()
    #fit the linear regression to the data
    lm = lm.fit(X_train, y_train)

    y_train_pred = lm.predict(X_train)

    train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))
    
    #use fitted model to predict on the test examples
    y_test_pred = lm.predict(X_test)

    #evaluate the predictions on the test examples
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
    
    return {'train_rmse': train_rmse, 'test_rmse' : test_rmse}

# %%
def test_data_log_target(features, target):
    X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 15, test_size=0.2)
    
    y_log = np.log(y_train)
    #instantiate a linear regression object
    lm_log = LinearRegression()
    #fit the linear regression to the data
    lm_log = lm_log.fit(X_train, y_log)

    log_train_pred  = lm_log.predict(X_train)
    #log_train_pred the predictions to get them on the same original scale 
    y_train_pred = np.exp(log_train_pred)

    train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))
    
    #use fitted model to predict on the test examples
    
    log_test_pred = lm_log.predict(X_test)
    #get test predictions back to original scale
    y_test_pred = np.exp(log_test_pred)
    
    #evaluate the predictions on the test examples
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
    
    return {'train_rmse': train_rmse, 'test_rmse' : test_rmse}

# %%
def residual_plot(features, target):
    X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 15, test_size=0.2)
    #instantiate a linear regression object
    lm = LinearRegression()
    #fit the linear regression to the data
    lm = lm.fit(X_train, y_train)

    y_train_pred = lm.predict(X_train)

    
    #use fitted model to predict on the test examples
    y_test_pred = lm.predict(X_test)


    return sns.residplot( y_test, y_test_pred,lowess=True, color="g")

# %%
def residual_plot_log(features, target):
    X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 15, test_size=0.2)
    
    y_log = np.log(y_train)
    #instantiate a linear regression object
    lm_log = LinearRegression()
    #fit the linear regression to the data
    lm_log = lm_log.fit(X_train, y_log)

    log_train_pred  = lm_log.predict(X_train)
    #log_train_pred the predictions to get them on the same original scale 
    y_train_pred = np.exp(log_train_pred)

    train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))
    
    #use fitted model to predict on the test examples
    
    log_test_pred = lm_log.predict(X_test)
    #get test predictions back to original scale
    y_test_pred = np.exp(log_test_pred)
    
    #evaluate the predictions on the test examples
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))

    return sns.residplot( y_test, y_test_pred,lowess=True, color="g")

# %% [markdown]
# ### Basic Model

# %%
#feature I selected based on my preliminary EDA and some trial and error
features= [
 'sqft_living',
 'zip_mean_income',
 'view_cat_great_view',
 'view_cat_good_view',
 'view_cat_ok_view',
 'excess_bathrooms_cat_2_or_less',
 'excess_bathrooms_cat_1_less',
 'excess_bathrooms_cat_1_or_more',
 'decade_built_adjusted_Pre-war',
 'decade_built_adjusted_1940s',
 'decade_built_adjusted_1950s',
 'decade_built_adjusted_1960s',
 'decade_built_adjusted_1970s',
 'decade_built_adjusted_1980s',
 'decade_built_adjusted_1990s',
 'decade_built_adjusted_2000s',
 'grade_cat_6',
 'grade_cat_7',
 'grade_cat_8',
 'grade_cat_9',
 'grade_cat_10',
 'grade_cat_11',
 'grade_cat_12',
 'grade_cat_13'
]

df_features = df[features]

target = df['price']

# %%
test_data(df_features, target)
# Out:
# {'train_rmse': 196090.98148453448, 'test_rmse': 176947.49146244617}

# %%
residual_plot(df_features, target)

# %% [markdown]
# My initial RMSE on the training data is under 200k. Pretty good. Lets see what logging the price does on these same features

# %%
test_data_log_target(df_features, target)
# Out:
# {'train_rmse': 186494.92810235757, 'test_rmse': 183771.6787668403}

# %%
residual_plot_log(df_features, target)

# %% [markdown]
# Tough to tell if logging price worked. It did better on the training data but worse on the testing. It

# %% [markdown]
# ---

# %% [markdown]
# Let's try select K Best on the all the basic features to see if that will come up with some better result than what I personally selected

# %%
df_Kbasic = df.drop(columns = ['price', 'id', 'date', 'lat', 'long', 'zipcode', 'grade', 'view'], axis = 1)

target = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(df_Kbasic, target, random_state = 15, test_size=0.2)

# %%
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

selector = SelectKBest(f_regression, k=30)

selector.fit(X_train, y_train)
# Out:
# SelectKBest(k=30, score_func=<function f_regression at 0x7fa454f209d0>)

# %%
selector.get_support()
# Out:
# array([ True,  True,  True, False,  True,  True,  True,  True, False,
#         True,  True, False, False, False,  True,  True, False,  True,
#        False,  True, False, False,  True,  True,  True,  True, False,
#        False,  True, False, False, False, False, False, False, False,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True, False,  True,  True, False, False, False, False,
#        False, False, False, False])

# %%
selected_columns = X_train.columns[selector.get_support()]

# %%
list(selected_columns)
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'floors',
#  'waterfront',
#  'sqft_above',
#  'sqft_basement',
#  'yr_renovated',
#  'sqft_living15',
#  'year_most_recent_construction',
#  'years_since_most_recent_construction',
#  'waterfront_view',
#  'zip_mean_income',
#  'zip_incomeXsqft_living',
#  'waterfrontXsqft_living',
#  'zip_incomeXsqft_lot',
#  'sqft_living^2',
#  'yearsince_mrcXsqft_living',
#  'grade_cat_10',
#  'grade_cat_11',
#  'grade_cat_12',
#  'grade_cat_13',
#  'grade_cat_6',
#  'grade_cat_7',
#  'grade_cat_9',
#  'view_cat_good_view',
#  'view_cat_great_view',
#  'view_cat_ok_view',
#  'excess_bathrooms_cat_1_or_more',
#  'excess_bathrooms_cat_2_or_less']

# %%
test_data(df[selected_columns], target)
# Out:
# {'train_rmse': 180465.86174294652, 'test_rmse': 169043.37987491192}

# %% [markdown]
# Pretty good! Lowest test RMSE so far though slightly higher variance.

# %%
redisual_plot(df[selected_columns], target)

# %% [markdown]
# Let's test the K best on log price

# %%
test_data_log_target(df[selected_columns], target)
# Out:
# {'train_rmse': 186058.34784145365, 'test_rmse': 180154.16158522395}

# %%
residual_plot_log(df[selected_columns], target)

# %% [markdown]
# Not as good this time around

# %% [markdown]
# Let's try iterating through different K's do see if I can find the best number K

# %%
len(df_Kbasic.columns)
# Out:
# 58

# %%
kbest_result = pd.DataFrame(columns = ['k', 'log_price','train_rmse','test_rmse' ])
X_train, X_test, y_train, y_test = train_test_split(df_Kbasic, target, random_state = 15, test_size=0.2)

# %%
for n in range(5,55):
    selector = SelectKBest(f_regression, k=n)

    selector.fit(X_train, y_train)
    
    selected_columns = X_train.columns[selector.get_support()]
    
    train_rmse = test_data(df[selected_columns], target)['train_rmse']
    
    test_rmse = test_data(df[selected_columns], target)['test_rmse']
    
    kbest_result = kbest_result.append({'k': n, 'log_price' : 'no', 'train_rmse': train_rmse, 'test_rmse': test_rmse}, ignore_index = True)

# %% [markdown]
# And for completeness lets do the same but log price

# %%
for n in range(5,55):
    selector = SelectKBest(f_regression, k=n)

    selector.fit(X_train, np.log(y_train))
    
    selected_columns = X_train.columns[selector.get_support()]
    
    train_rmse = test_data_log_target(df[selected_columns], target)['train_rmse']
    
    test_rmse = test_data_log_target(df[selected_columns], target)['test_rmse']
    
    kbest_result  = kbest_result.append({'k': n, 'log_price' : 'yes', 'train_rmse': train_rmse, 'test_rmse': test_rmse}, ignore_index = True)

# %%
kbest_result.sort_values('test_rmse').head(10)
# Out:
#      k log_price     train_rmse      test_rmse
# 93  48       yes  139636.043440  128780.029040
# 94  49       yes  139614.882777  128810.147381
# 96  51       yes  139612.652653  128827.626460
# 95  50       yes  139624.585493  128837.150114
# 99  54       yes  139670.003618  128882.597598
# 92  47       yes  139758.297201  128888.489116
# 97  52       yes  139681.999539  128934.493661
# 98  53       yes  139697.585559  128972.281955
# 91  46       yes  139874.323991  129090.318668
# 90  45       yes  140393.147038  129129.773061

# %% [markdown]
# Seems like 48 features along with logging price hits the sweet spot of lower test_rmse train_rmse is correspondigly low as well so I am not overly concerned about the variance. But with 49 features, there still may be some overfitting occuring.
#
# Lets see the residual plot for that regression

# %%
selector = SelectKBest(f_regression, k=48)

selector.fit(X_train, np.log(y_train))

selected_columns = X_train.columns[selector.get_support()]

residual_plot_log(df[selected_columns], target)

# %% [markdown]
# That's actually a pretty decent looking residual plot!

# %% [markdown]
# ---

# %% [markdown]
# Now let's try recursive feature elimination

# %%
from sklearn.feature_selection import RFECV

# %%
df_rfe = df.drop(columns = ['price', 'id', 'date', 'lat', 'long', 'zipcode', 'grade', 'view'], axis = 1)

target = df['price']

X_train, X_test, y_train, y_test = train_test_split(df_features, target, random_state = 15, test_size=0.2)

# %%
ols = LinearRegression()
# Create recursive feature eliminator that scores features by mean squared errors
selector = RFECV(estimator=ols, step=1, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)

# Fit recursive feature eliminator 
selector.fit(X_train, y_train)
# Out:
# RFECV(cv=5, estimator=LinearRegression(), n_jobs=-1,
#       scoring='neg_mean_squared_error', verbose=1)

# %%
#get feature column names
selected_rfe = X_train.columns[selector.support_]

# %%
len(list(selected_rfe))
# Out:
# 24

# %%
selected_rfe
# Out:
# Index(['sqft_living', 'zip_mean_income', 'view_cat_great_view',
#        'view_cat_good_view', 'view_cat_ok_view',
#        'excess_bathrooms_cat_2_or_less', 'excess_bathrooms_cat_1_less',
#        'excess_bathrooms_cat_1_or_more', 'decade_built_adjusted_Pre-war',
#        'decade_built_adjusted_1940s', 'decade_built_adjusted_1950s',
#        'decade_built_adjusted_1960s', 'decade_built_adjusted_1970s',
#        'decade_built_adjusted_1980s', 'decade_built_adjusted_1990s',
#        'decade_built_adjusted_2000s', 'grade_cat_6', 'grade_cat_7',
#        'grade_cat_8', 'grade_cat_9', 'grade_cat_10', 'grade_cat_11',
#        'grade_cat_12', 'grade_cat_13'],
#       dtype='object')

# %%
test_data(df[selected_rfe], df['price'])
# Out:
# {'train_rmse': 196090.98148453448, 'test_rmse': 176947.49146244617}

# %%
residual_plot(df[selected_rfe], df['price'])

# %% [markdown]
# Now let try that with log price which has had some success so far with other models

# %%
ols = LinearRegression()
# Create recursive feature eliminator that scores features by mean squared errors
selector = RFECV(estimator=ols, step=1, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)

# Fit recursive feature eliminator 
selector.fit(X_train, np.log(y_train))
# Out:
# RFECV(cv=5, estimator=LinearRegression(), n_jobs=-1,
#       scoring='neg_mean_squared_error', verbose=1)

# %%
selected_rfe = X_train.columns[selector.support_]

# %%
len(list(selected_rfe))
# Out:
# 58

# %%
test_data_log_target(df[selected_rfe], df['price'])
# Out:
# {'train_rmse': 139304.1538332672, 'test_rmse': 128703.26580233562}

# %%
residual_plot_log(df[selected_rfe], df['price'])
